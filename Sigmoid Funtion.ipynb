# %%
# Import matplotlib, numpy and math
import matplotlib.pyplot as plt
import numpy as np
import math
  
df = pd.read_csv('Salary_Data.csv',encoding="ISO-8859-1")
x1 = np.array((df.YearsExperience))
y2 = np.array((df.Salary))
slope, intercept, r, p, std_err = stats.linregress(x, y)


x = np.linspace(-100, 100, 200)
z = 1/(1 + np.exp(-x))
  
plt.plot(x, z)
plt.xlabel("x")
plt.ylabel("Sigmoid(X)")
  
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd

# df = pd.read_csv('Salary_Data.csv')
df = pd.read_csv('Salary_Data.csv',encoding="ISO-8859-1")

x = np.array((df.YearsExperience))
y = np.array((df.Salary))

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

x1=int(input("enter the exp "))
y1=myfunc(x1)

print("The value of salary for expereince ",x1," is $",y1)
# Out:
# enter the exp 4
# The value of salary for expereince  4  is $ 63592.049484489
